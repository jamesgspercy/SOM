# %% [markdown]
# ## Virtual Pharmacology Lab Worksheet
#
# RA(Dose) determines degree of Receptor Activation RA for a give dose A as RA=F*Rt*E*(A/(A+Kd))
#
# Effect(C-T) determines gross effect as %MPE in assay given Threshold T and Ceiling C as Effect=((RA-T)/(C-T))*100
#
# Effect(Assay) sets all values ≤0 to 0 and all values ≥100 to 100
#
# $\hat{Y} = \hat{\beta}_{0} + \sum \limits _{j=1} ^{p} X_{j}\hat{\beta}_{j} $
#
# ${RA} = {F}\times{Rt}$
#
#
# | Column 1       | Column 2     |
# | :------------- | :----------: |
# |  Cell Contents | More Stuff   |
# | You Can Also   | Put Pipes In |

# %%
#EXP1

## Set your dose

dose = []

## Parameters

F = 
Rt = 
E = 
Kd = 
threshold = 
capacity =

# %%
#EXP2

## Set your dose

dose2 = [0.1,0.32,1.0,3.2,10,32]

## Parameters

ex2_F = 1
ex2_Rt = 75
ex2_E = 1
ex2_Kd = 1
ex2_threshold = 0
ex2_capacity = 100

# %%
#EXP3

## Set your dose

dose3 = [0.1,0.32,1.0,3.2,10,32]

## Parameters

ex3_F = 1
ex3_Rt = 50
ex3_E = 1
ex3_Kd = 1
ex3_threshold = 0
ex3_capacity = 100

# %%
#EXP4

dose4 = [0.1,0.32,1.0,3.2,10,32]

## Parameters

ex4_F = 1
ex4_Rt = 25
ex4_E = 1
ex4_Kd = 1
ex4_threshold = 0
ex4_capacity = 100

# %%
## Run the calculation and render plots

# %run -i calculate.py
# Out:
#    RA(Dose)  Effect(C-T)  Effect(Assay)
# 0      0.10         -1.0           7.18
# 1      0.32         -0.5          19.15
# 2      1.00          0.0          39.50
# 3      3.20          0.5          60.19
# 4     10.00          1.0          71.82
# 5     32.00          1.5          76.61
#    RA(Dose)  Effect(C-T)  Effect(Assay)
# 0      0.10         -1.0           7.18
# 1      0.32         -0.5          19.15
# 2      1.00          0.0          39.50
# 3      3.20          0.5          60.19
# 4     10.00          1.0          71.82
# 5     32.00          1.5          76.61
#    RA(Dose)  Effect(C-T)  Effect(Assay)
# 0      0.10         -1.0           7.18
# 1      0.32         -0.5          19.15
# 2      1.00          0.0          39.50
# 3      3.20          0.5          60.19
# 4     10.00          1.0          71.82
# 5     32.00          1.5          76.61
#    RA(Dose)  Effect(C-T)  Effect(Assay)
# 0      0.10         -1.0           7.18
# 1      0.32         -0.5          19.15
# 2      1.00          0.0          39.50
# 3      3.20          0.5          60.19
# 4     10.00          1.0          71.82
# 5     32.00          1.5          76.61
